# %%
import pandas as pd

# %%
df = pd.read_csv("data-southsudan-waterlocations.csv")
df
# Out:
#      row_id                                             source   lat_deg  \
# 0     39767  Water Information Management System (WIMS) dev...  4.010580
# 1     40187  Water Information Management System (WIMS) dev...  5.541667
# 2     34890                              Water for South Sudan  8.410310
# 3     39891  Water Information Management System (WIMS) dev...  4.378000
# 4     35346                              Water for South Sudan  8.135450
# ..      ...                                                ...       ...
# 995   45102  Water Information Management System (WIMS) dev...  5.040000
# 996   41565  Water Information Management System (WIMS) dev...  8.180010
# 997   44113  Water Information Management System (WIMS) dev...  7.777633
# 998   44080  Water Information Management System (WIMS) dev...  7.581867
# 999   43037  Water Information Management System (WIMS) dev...  9.002933
#
#        lon_deg              report_date status_id water_source  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   row_id                   1000 non-null   int64
#  1   source                   1000 non-null   object
#  2   lat_deg                  1000 non-null   float64
#  3   lon_deg                  1000 non-null   float64
#  4   report_date              1000 non-null   object
#  5   status_id                1000 non-null   object
#  6   water_source             1000 non-null   object
#  7   water_source_clean       998 non-null    object
#  8   water_tech_clean         442 non-null    object
#  9   water_tech               444 non-null    object
#  10  _facility_type           998 non-null    object
#  11  country_name             1000 non-null   object
#  12  adm1                     1000 non-null   object
#  13  adm2                     968 non-null    object
# ...

# %%
unimproved = df["_facility_type"] == "Unimproved"
df[unimproved]
# Out:
#      row_id                                             source  lat_deg  \
# 7     36910  Water Information Management System (WIMS) dev...  3.69911
# 95    36917  Water Information Management System (WIMS) dev...  3.59706
# 100   39762  Water Information Management System (WIMS) dev...  3.95023
# 108   39791  Water Information Management System (WIMS) dev...  4.48705
# 123   39772  Water Information Management System (WIMS) dev...  3.95627
# 178   39776  Water Information Management System (WIMS) dev...  3.85089
# 180   39846  Water Information Management System (WIMS) dev...  4.28951
# 200   39808  Water Information Management System (WIMS) dev...  4.10258
# 210   36893  Water Information Management System (WIMS) dev...  3.76000
# 214   39761  Water Information Management System (WIMS) dev...  3.94151
# 215   39759  Water Information Management System (WIMS) dev...  3.95627
# 238   36911  Water Information Management System (WIMS) dev...  3.69155
# ...

# %%
boreholes = df["water_source"] == "Borehole"
df[boreholes]
# Out:
#      row_id                                             source   lat_deg  \
# 0     39767  Water Information Management System (WIMS) dev...  4.010580
# 1     40187  Water Information Management System (WIMS) dev...  5.541667
# 2     34890                              Water for South Sudan  8.410310
# 3     39891  Water Information Management System (WIMS) dev...  4.378000
# 4     35346                              Water for South Sudan  8.135450
# ..      ...                                                ...       ...
# 995   45102  Water Information Management System (WIMS) dev...  5.040000
# 996   41565  Water Information Management System (WIMS) dev...  8.180010
# 997   44113  Water Information Management System (WIMS) dev...  7.777633
# 998   44080  Water Information Management System (WIMS) dev...  7.581867
# 999   43037  Water Information Management System (WIMS) dev...  9.002933
#
#        lon_deg              report_date status_id water_source  \
# ...

# %%
repairs = df["status"] == "needs repairs"
df[repairs]
# Out:
#      row_id                                             source   lat_deg  \
# 9     39974  Water Information Management System (WIMS) dev...  4.786964
# 23    36993  Water Information Management System (WIMS) dev...  5.393110
# 28    36932  Water Information Management System (WIMS) dev...  5.514710
# 34    39597  Water Information Management System (WIMS) dev...  5.487050
# 40    39642  Water Information Management System (WIMS) dev...  5.798690
# ..      ...                                                ...       ...
# 978   41096  Water Information Management System (WIMS) dev...  6.010133
# 979   44433  Water Information Management System (WIMS) dev...  8.486483
# 981   43171  Water Information Management System (WIMS) dev...  9.436850
# 982   44540  Water Information Management System (WIMS) dev...  7.642933
# 997   44113  Water Information Management System (WIMS) dev...  7.777633
#
#        lon_deg              report_date status_id water_source  \
# ...

# %%
handpumps = df["water_tech_clean"] == "Hand Pump - India Mark"
df[handpumps]
# Out:
#      row_id                                             source   lat_deg  \
# 1     40187  Water Information Management System (WIMS) dev...  5.541667
# 2     34890                              Water for South Sudan  8.410310
# 4     35346                              Water for South Sudan  8.135450
# 8     40155  Water Information Management System (WIMS) dev...  5.487222
# 9     39974  Water Information Management System (WIMS) dev...  4.786964
# ..      ...                                                ...       ...
# 992   41143  Water Information Management System (WIMS) dev...  6.097733
# 994   43831  Water Information Management System (WIMS) dev...  7.803833
# 996   41565  Water Information Management System (WIMS) dev...  8.180010
# 997   44113  Water Information Management System (WIMS) dev...  7.777633
# 998   44080  Water Information Management System (WIMS) dev...  7.581867
#
#        lon_deg              report_date status_id water_source  \
# ...
